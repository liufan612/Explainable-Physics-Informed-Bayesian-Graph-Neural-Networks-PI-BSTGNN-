# %%
import pandas as pd
import numpy as np
import cudf  # RAPIDS cuDF for GPU DataFrame operations
from cuml.ensemble import RandomForestRegressor  # GPU-accelerated Random Forest
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch
import os
import matplotlib.pyplot as plt
import pickle

# 配置
config = {
    'num_estimators': 100,
    'max_depth': 10,
    'random_state': 42,
    'batch_size': 4,
    'save_path': './saved_models/dual_guass_rf',
    'num_epochs': 1,
    'patience': 30,
    'head_target_col': 'head',          # 水头目标列
    'conc_target_col': 'concentration'  # 浓度目标列
}

# 设备配置
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"使用设备: {device}")

# 计算评估指标
def compute_metrics(y_true, y_pred):
    """计算评估指标，正确处理cuDF/cuPy数组"""
    
    # 处理cuDF Series
    if hasattr(y_true, 'to_pandas'):
        y_true = y_true.to_pandas().values
    elif hasattr(y_true, 'get'):  # CuPy数组
        y_true = y_true.get()
    elif hasattr(y_true, 'values'):
        y_true = y_true.values
    
    if hasattr(y_pred, 'to_pandas'):
        y_pred = y_pred.to_pandas().values
    elif hasattr(y_pred, 'get'):  # CuPy数组
        y_pred = y_pred.get()
    elif hasattr(y_pred, 'values'):
        y_pred = y_pred.values
    
    # 确保为NumPy数组
    y_true = np.array(y_true).ravel()
    y_pred = np.array(y_pred).ravel()
    
    # 过滤空值和无穷值
    mask = ~np.isnan(y_true) & ~np.isinf(y_true) & ~np.isnan(y_pred) & ~np.isinf(y_pred)
    y_true_clean = y_true[mask]
    y_pred_clean = y_pred[mask]
    
    if len(y_true_clean) == 0:
        return {'mse': np.inf, 'rmse': np.inf, 'mae': np.inf, 'r2': -np.inf}
    
    mse = mean_squared_error(y_true_clean, y_pred_clean)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true_clean, y_pred_clean)
    r2 = r2_score(y_true_clean, y_pred_clean)
    
    return {'mse': mse, 'rmse': rmse, 'mae': mae, 'r2': r2}

def preprocess_data_for_rf(data):
    """
    将数据转换为适合随机森林的表格格式，与GNN特征完全一致
    水头模型：16维特征
    浓度模型：19维特征
    """
    print("开始预处理随机森林数据...")
    
    # 检查必要的列
    required_cols = [
        'row', 'col', 'time_step', 'x', 'y', 'top', 'bottom', 'K', 'recharge', 'ET',
        'river_stage', 'river_cond', 'river_rbot', 'well_rate', 'well_mask',
        'chd_mask', 'lytyp', 'conc_mask', 'head', 'concentration'
    ]
    
    missing_cols = [col for col in required_cols if col not in data.columns]
    if missing_cols:
        raise KeyError(f"缺少必要的列: {missing_cols}")
    
    # 数据类型转换，与GNN保持一致
    data = data.astype({
        'x': np.float32, 'y': np.float32, 'top': np.float32, 
        'bottom': np.float32, 'K': np.float32, 'recharge': np.float32,
        'ET': np.float32, 'river_stage': np.float32, 'river_cond': np.float32,
        'river_rbot': np.float32, 'well_rate': np.float32, 'well_mask': np.uint8,
        'chd_mask': np.uint8, 'lytyp': np.uint8, 'head': np.float32, 
        'concentration': np.float32, 'conc_mask': np.uint8
    })
    
    print(f"原始数据形状: {data.shape}")
    
    # 处理缺失值
    data = data.dropna(subset=required_cols)
    print(f"处理缺失值后数据形状: {data.shape}")
    
    # 时间步归一化（与GNN保持一致）
    time_min = data['time_step'].min()
    data['time_step'] = data['time_step'] - time_min
    
    # 按模型、行、列、时间步排序
    data = data.sort_values(['row', 'col', 'time_step'])
    
    # 基础特征列 - 与GNN的feature_cols保持一致 (14维)
    base_feature_cols = [
        'x', 'y', 'top', 'bottom', 'K', 'recharge', 'ET',
        'river_stage', 'river_cond', 'river_rbot', 'well_rate', 'well_mask',
        'chd_mask', 'lytyp'
    ]
    
    # 浓度模型额外的基础特征 (15维，增加conc_mask)
    conc_base_feature_cols = base_feature_cols + ['conc_mask']
    
    print("计算历史特征...")
    
    # 计算前一时间步和前两个时间步的水头和浓度
    prev_head = np.zeros(len(data), dtype=np.float32)
    prev2_head = np.zeros(len(data), dtype=np.float32)
    prev_conc = np.zeros(len(data), dtype=np.float32)
    prev2_conc = np.zeros(len(data), dtype=np.float32)
    
    # 按行列分组处理历史特征
    groups = data.groupby(['row', 'col'], sort=False)
    for (row, col), group in groups:
        time_series = group.sort_values('time_step')
        indices = time_series.index
        
        # 使用numpy.roll计算历史特征
        head_values = time_series['head'].values
        conc_values = time_series['concentration'].values
        
        prev_head[indices] = np.roll(head_values, 1)
        prev2_head[indices] = np.roll(head_values, 2)
        prev_conc[indices] = np.roll(conc_values, 1)
        prev2_conc[indices] = np.roll(conc_values, 2)
        
        # 处理第一个时间步
        first_idx = indices[0]
        if len(indices) > 1:
            second_idx = indices[1]
            # 第一个时间步使用自身值
            prev_head[first_idx] = head_values[0]
            prev2_head[first_idx] = head_values[0]
            prev_conc[first_idx] = conc_values[0]
            prev2_conc[first_idx] = conc_values[0]
            
            # 第二个时间步的prev2使用第一个时间步的值
            prev2_head[second_idx] = head_values[0]
            prev2_conc[second_idx] = conc_values[0]
        else:
            # 只有一个时间步的情况
            prev_head[first_idx] = head_values[0]
            prev2_head[first_idx] = head_values[0]
            prev_conc[first_idx] = conc_values[0]
            prev2_conc[first_idx] = conc_values[0]
    
    # 将历史特征添加到数据中
    data['prev_head'] = prev_head
    data['prev2_head'] = prev2_head
    data['prev_conc'] = prev_conc
    data['prev2_conc'] = prev2_conc
    
    print("历史特征计算完成")
    
    # 构建特征矩阵
    # 水头模型特征：基础特征(14维) + 前一/前二时间步水头(2维) = 16维
    head_feature_cols = base_feature_cols + ['prev_head', 'prev2_head']
    X_head = data[head_feature_cols].values.astype(np.float32)
    
    # 浓度模型特征：基础特征+conc_mask(15维) + 前一/前二时间步水头(2维) + 前一/前二时间步浓度(2维) = 19维
    conc_feature_cols = conc_base_feature_cols + ['prev_head', 'prev2_head', 'prev_conc', 'prev2_conc']
    X_conc = data[conc_feature_cols].values.astype(np.float32)
    
    print(f"水头模型特征维度: {X_head.shape[1]} (期望16维)")
    print(f"浓度模型特征维度: {X_conc.shape[1]} (期望19维)")
    
    # 特征标准化 - 只对浮点数特征进行标准化
    # 识别浮点数特征索引
    def get_float_indices(feature_cols, data_dtypes):
        float_indices = []
        uint8_cols = ['well_mask', 'chd_mask', 'lytyp', 'conc_mask']
        for i, col in enumerate(feature_cols):
            if col not in uint8_cols:
                float_indices.append(i)
        return float_indices
    
    # 水头模型特征标准化
    head_float_indices = get_float_indices(head_feature_cols, data.dtypes)
    head_scaler = StandardScaler()
    X_head_scaled = X_head.copy()
    X_head_scaled[:, head_float_indices] = head_scaler.fit_transform(X_head[:, head_float_indices])
    
    # 浓度模型特征标准化
    conc_float_indices = get_float_indices(conc_feature_cols, data.dtypes)
    conc_scaler = StandardScaler()
    X_conc_scaled = X_conc.copy()
    X_conc_scaled[:, conc_float_indices] = conc_scaler.fit_transform(X_conc[:, conc_float_indices])
    
    # 处理异常值
    X_head_scaled = np.nan_to_num(X_head_scaled, nan=0.0, posinf=1e6, neginf=-1e6)
    X_conc_scaled = np.nan_to_num(X_conc_scaled, nan=0.0, posinf=1e6, neginf=-1e6)
    
    # 目标变量
    y_head = data['head'].values.astype(np.float32)
    y_conc = data['concentration'].values.astype(np.float32)
    
    # 索引信息
    index_data = data[['row', 'col', 'time_step']].copy()
    
    print("数据预处理完成!")
    print(f"最终特征形状 - 水头: {X_head_scaled.shape}, 浓度: {X_conc_scaled.shape}")
    print(f"目标变量形状 - 水头: {y_head.shape}, 浓度: {y_conc.shape}")
    
    return (X_head_scaled, X_conc_scaled, y_head, y_conc, 
            head_scaler, conc_scaler, head_feature_cols, conc_feature_cols, index_data)

def train_rf():
    # 加载数据
    cleaned_data = pd.read_csv('conc_dual_guass.csv')
    
    # 预处理数据，获取水头和浓度的特征矩阵
    X_head, X_conc_base, y_head, y_conc, scaler_head, scaler_conc, head_feature_cols, conc_feature_cols, index_data = preprocess_data_for_rf(cleaned_data)
    
    # 转换为 cuDF 以进行 GPU 处理
    X_head_cudf = cudf.DataFrame(X_head)
    y_head_cudf = cudf.Series(y_head)
    y_conc_cudf = cudf.Series(y_conc)
    
    # 初始化 KFold
    print("初始化 10 折交叉验证...")
    kf = KFold(n_splits=10, shuffle=True, random_state=config['random_state'])
    
    # 初始化指标存储
    head_train_metrics_all = []
    conc_train_metrics_all = []
    head_test_metrics_all = []
    conc_test_metrics_all = []
    predictions_all = []
    
    # 创建特征重要性存储
    head_feature_importance = np.zeros(X_head.shape[1])
    conc_feature_importance = np.zeros(X_conc_base.shape[1] + 1)  # +1 for predicted head
    
    # 执行 10 折交叉验证
    for fold, (train_idx, test_idx) in enumerate(kf.split(X_head_cudf)):
        print(f"\n处理第 {fold + 1}/10 折...")
        
        # 划分数据 - 水头模型
        X_head_train = X_head_cudf.iloc[train_idx]
        X_head_test = X_head_cudf.iloc[test_idx]
        y_head_train = y_head_cudf.iloc[train_idx]
        y_head_test = y_head_cudf.iloc[test_idx]
        
        # 划分数据 - 浓度模型基础数据（尚未包括预测的水头）
        X_conc_base_cudf = cudf.DataFrame(X_conc_base)
        X_conc_train_base = X_conc_base_cudf.iloc[train_idx]
        X_conc_test_base = X_conc_base_cudf.iloc[test_idx]
        y_conc_train = y_conc_cudf.iloc[train_idx]
        y_conc_test = y_conc_cudf.iloc[test_idx]
        
        # 验证形状
        print(f"第 {fold + 1} 折 - 训练集形状: X_head_train={X_head_train.shape}, y_head_train={len(y_head_train)}")
        print(f"第 {fold + 1} 折 - 测试集形状: X_head_test={X_head_test.shape}, y_head_test={len(y_head_test)}")
        
        # 检查 X_head_train 中的 NaN 或无穷值
        print(f"第 {fold + 1} 折 - 检查 X_head_train 中的 NaN 或无穷值:")
        print("NaN:", X_head_train.isnull().sum().sum())
        print("无穷值:", (X_head_train == float('inf')).sum().sum() + (X_head_train == -float('inf')).sum().sum())
        
        # 初始化随机森林模型 - 水头
        head_rf = RandomForestRegressor(
            n_estimators=config['num_estimators'],
            max_depth=config['max_depth'],
            random_state=config['random_state'],
            n_streams=1
        )
        
        # 训练水头模型
        print(f"第 {fold + 1} 折 - 训练水头随机森林模型...")
        head_rf.fit(X_head_train, y_head_train)
        
        # 获取水头模型的特征重要性 - 使用cuML RandomForestRegressor的正确方法
        # cuML 中使用 get_feature_importance() 方法而不是 feature_importances_ 属性
        try:
            # 尝试使用cuML的方法获取特征重要性
            head_importance = head_rf.get_feature_importances()
            head_feature_importance += head_importance.to_numpy()
            
            # 输出水头模型的特征重要性
            print(f"第 {fold + 1} 折 - 水头模型的特征重要性 (前5):")
            head_importance_df = pd.DataFrame({
                'feature': head_feature_cols,
                'importance': head_importance.to_numpy()
            }).sort_values('importance', ascending=False)
            print(head_importance_df.head(5))
        except Exception as e:
            print(f"无法获取水头模型的特征重要性: {e}")
            print("跳过特征重要性分析，继续训练...")
        
        # 为浓度模型准备训练数据（加入预测的水头）
        print(f"第 {fold + 1} 折 - 准备浓度训练数据...")
        pred_head_train = head_rf.predict(X_head_train)
        X_conc_train = X_conc_train_base.copy()
        X_conc_train['pred_head'] = pred_head_train
        
        # 检查 pred_head_train 中的 NaN
        print(f"第 {fold + 1} 折 - pred_head_train 中的 NaN:", pred_head_train.isnull().sum())
        if X_conc_train['pred_head'].isnull().sum() > 0:
            print(f"第 {fold + 1} 折 - 警告: X_conc_train['pred_head'] 包含 {X_conc_train['pred_head'].isnull().sum()} 个 NaN 值，填充为均值")
            X_conc_train['pred_head'] = X_conc_train['pred_head'].fillna(X_conc_train['pred_head'].mean())
        
        # 初始化随机森林模型 - 浓度
        conc_rf = RandomForestRegressor(
            n_estimators=config['num_estimators'],
            max_depth=config['max_depth'],
            random_state=config['random_state'],
            n_streams=1
        )
        
        # 训练浓度模型
        print(f"第 {fold + 1} 折 - 训练浓度随机森林模型...")
        pred_head_test = head_rf.predict(X_head_test)
        X_conc_test = X_conc_test_base.copy()
        X_conc_test['pred_head'] = pred_head_test
        
        if X_conc_test['pred_head'].isnull().sum() > 0:
            print(f"第 {fold + 1} 折 - 警告: X_conc_test['pred_head'] 包含 {X_conc_test['pred_head'].isnull().sum()} 个 NaN 值，填充为均值")
            X_conc_test['pred_head'] = X_conc_test['pred_head'].fillna(X_conc_test['pred_head'].mean())
        
        conc_rf.fit(X_conc_train, y_conc_train)
        
        # 获取浓度模型的特征重要性 - 使用cuML RandomForestRegressor的正确方法
        try:
            # 尝试使用cuML的方法获取特征重要性
            conc_importance = conc_rf.get_feature_importances()
            conc_feature_importance += conc_importance.to_numpy()
            
            # 输出浓度模型的特征重要性
            print(f"第 {fold + 1} 折 - 浓度模型的特征重要性 (前5):")
            conc_feature_names = conc_feature_cols + ['pred_head']
            conc_importance_df = pd.DataFrame({
                'feature': conc_feature_names,
                'importance': conc_importance.to_numpy()
            }).sort_values('importance', ascending=False)
            print(conc_importance_df.head(5))
        except Exception as e:
            print(f"无法获取浓度模型的特征重要性: {e}")
            print("跳过特征重要性分析，继续训练...")
        
        # 在训练集上评估
        head_train_pred = head_rf.predict(X_head_train)
        conc_train_pred = conc_rf.predict(X_conc_train)
        
        head_train_metrics = compute_metrics(y_head_train, head_train_pred)
        conc_train_metrics = compute_metrics(y_conc_train, conc_train_pred)
        head_train_metrics_all.append(head_train_metrics)
        conc_train_metrics_all.append(conc_train_metrics)
        
        # 在测试集上评估
        head_test_pred = head_rf.predict(X_head_test)
        conc_test_pred = conc_rf.predict(X_conc_test)
        
        head_test_metrics = compute_metrics(y_head_test, head_test_pred)
        conc_test_metrics = compute_metrics(y_conc_test, conc_test_pred)
        head_test_metrics_all.append(head_test_metrics)
        conc_test_metrics_all.append(conc_test_metrics)
        
        # 保存预测结果
        index_test = index_data.iloc[test_idx]
        predictions = {
            'fold': np.full(len(test_idx), fold + 1),
            'row': index_test['row'].values,
            'col': index_test['col'].values,
            'time_step': index_test['time_step'].values,
            'pred_conc': conc_test_pred.to_pandas().values,
            'true_conc': y_conc_test.to_pandas().values,
            'pred_head': head_test_pred.to_pandas().values,
            'true_head': y_head_test.to_pandas().values
        }
        predictions_all.append(pd.DataFrame(predictions))
    
    # 保存模型（使用最后一折的模型）
    os.makedirs(config['save_path'], exist_ok=True)
    try:
        # 尝试使用 cuML 原生的保存方法
        head_rf.save(os.path.join(config['save_path'], 'head_rf_model.pkl'))
        conc_rf.save(os.path.join(config['save_path'], 'conc_rf_model.pkl'))
    except Exception as e:
        print(f"无法使用 cuML 原生方法保存模型: {e}")
        print("尝试使用 pickle 保存...")
        try:
            with open(os.path.join(config['save_path'], 'head_rf_model.pkl'), 'wb') as f:
                pickle.dump(head_rf, f)
            with open(os.path.join(config['save_path'], 'conc_rf_model.pkl'), 'wb') as f:
                pickle.dump(conc_rf, f)
        except Exception as e2:
            print(f"无法使用 pickle 保存模型: {e2}")
            print("模型将不会被保存。")
    
    # 保存标准化器
    with open(os.path.join(config['save_path'], 'scaler_head.pkl'), 'wb') as f:
        pickle.dump(scaler_head, f)
    with open(os.path.join(config['save_path'], 'scaler_conc.pkl'), 'wb') as f:
        pickle.dump(scaler_conc, f)
    
    # 合并并保存预测结果
    predictions_df = pd.concat(predictions_all, ignore_index=True)
    predictions_df.to_csv(os.path.join(config['save_path'], 'test_predictions_rf_kfold.csv'), index=False)
    
    # 尝试保存特征重要性（如果可用）
    try:
        # 计算平均特征重要性
        head_feature_importance /= 10  # 10折交叉验证
        conc_feature_importance /= 10  # 10折交叉验证
        
        # 保存特征重要性
        head_importance_final = pd.DataFrame({
            'feature': head_feature_cols,
            'importance': head_feature_importance
        }).sort_values('importance', ascending=False)
        
        conc_importance_final = pd.DataFrame({
            'feature': conc_feature_cols + ['pred_head'],
            'importance': conc_feature_importance
        }).sort_values('importance', ascending=False)
        
        head_importance_final.to_csv(os.path.join(config['save_path'], 'head_feature_importance.csv'), index=False)
        conc_importance_final.to_csv(os.path.join(config['save_path'], 'conc_feature_importance.csv'), index=False)
        
        # 绘制特征重要性图表
        plt.figure(figsize=(12, 8))
        
        # 水头模型特征重要性
        plt.subplot(2, 1, 1)
        head_top10 = head_importance_final.head(10)
        plt.barh(head_top10['feature'], head_top10['importance'])
        plt.title('水头模型特征重要性 (前10)')
        plt.xlabel('重要性')
        plt.gca().invert_yaxis()  # 从上到下显示
        
        # 浓度模型特征重要性
        plt.subplot(2, 1, 2)
        conc_top10 = conc_importance_final.head(10)
        plt.barh(conc_top10['feature'], conc_top10['importance'])
        plt.title('浓度模型特征重要性 (前10)')
        plt.xlabel('重要性')
        plt.gca().invert_yaxis()  # 从上到下显示
        
        plt.tight_layout()
        plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
        
    except Exception as e:
        print(f"无法保存或绘制特征重要性: {e}")
        print("跳过特征重要性分析，继续评估...")
    
    # 计算平均指标
    def average_metrics(metrics_list):
        keys = metrics_list[0].keys()
        avg_metrics = {key: np.mean([m[key] for m in metrics_list]) for key in keys}
        return avg_metrics
    
    avg_head_train_metrics = average_metrics(head_train_metrics_all)
    avg_conc_train_metrics = average_metrics(conc_train_metrics_all)
    avg_head_test_metrics = average_metrics(head_test_metrics_all)
    avg_conc_test_metrics = average_metrics(conc_test_metrics_all)
    
    # 输出结果
    print("\n📊 平均训练集结果 (10折交叉验证):")
    print("\n🔹 水头指标:")
    for k, v in avg_head_train_metrics.items():
        print(f"{k.upper():<5}: {v:.4f}")
    print("\n🔹 浓度指标:")
    for k, v in avg_conc_train_metrics.items():
        print(f"{k.upper():<5}: {v:.4f}")
    
    print("\n📊 平均测试集结果 (10折交叉验证):")
    print("\n🔹 水头指标:")
    for k, v in avg_head_test_metrics.items():
        print(f"{k.upper():<5}: {v:.4f}")
    print("\n🔹 浓度指标:")
    for k, v in avg_conc_test_metrics.items():
        print(f"{k.upper():<5}: {v:.4f}")
    
    # 绘制预测与真实值对比图
    try:
        plt.figure(figsize=(12, 10))
        
        # 水头预测
        plt.subplot(2, 1, 1)
        all_pred_head = np.concatenate([df['pred_head'].values for df in predictions_all])
        all_true_head = np.concatenate([df['true_head'].values for df in predictions_all])
        plt.scatter(all_true_head, all_pred_head, alpha=0.3)
        min_val = min(all_true_head.min(), all_pred_head.min())
        max_val = max(all_true_head.max(), all_pred_head.max())
        plt.plot([min_val, max_val], [min_val, max_val], 'r--')
        plt.title(f'水头预测 vs 真实值 (R² = {avg_head_test_metrics["r2"]:.4f})')
        plt.xlabel('真实水头')
        plt.ylabel('预测水头')
        
        # 浓度预测
        plt.subplot(2, 1, 2)
        all_pred_conc = np.concatenate([df['pred_conc'].values for df in predictions_all])
        all_true_conc = np.concatenate([df['true_conc'].values for df in predictions_all])
        plt.scatter(all_true_conc, all_pred_conc, alpha=0.3)
        min_val = min(all_true_conc.min(), all_pred_conc.min())
        max_val = max(all_true_conc.max(), all_pred_conc.max())
        plt.plot([min_val, max_val], [min_val, max_val], 'r--')
        plt.title(f'浓度预测 vs 真实值 (R² = {avg_conc_test_metrics["r2"]:.4f})')
        plt.xlabel('真实浓度')
        plt.ylabel('预测浓度')
        
        plt.tight_layout()
        plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
    except Exception as e:
        print(f"无法绘制预测图表: {e}")
        print("跳过图表绘制，继续返回结果...")
    
    return avg_head_train_metrics, avg_conc_train_metrics, avg_head_test_metrics, avg_conc_test_metrics

# 运行训练
avg_head_train_metrics, avg_conc_train_metrics, avg_head_test_metrics, avg_conc_test_metrics = train_rf()
# Out:
# 使用设备: cuda:0
# 开始预处理随机森林数据...
# 原始数据形状: (5328000, 22)
# 处理缺失值后数据形状: (5328000, 22)
# 计算历史特征...
# 历史特征计算完成
# 水头模型特征维度: 16 (期望16维)
# 浓度模型特征维度: 19 (期望19维)
# 数据预处理完成!
# 最终特征形状 - 水头: (5328000, 16), 浓度: (5328000, 19)
# 目标变量形状 - 水头: (5328000,), 浓度: (5328000,)
# 初始化 10 折交叉验证...
#
# 处理第 1/10 折...
# 第 1 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 1 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 1 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 1 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 1 折 - 准备浓度训练数据...
# 第 1 折 - pred_head_train 中的 NaN: 0
# 第 1 折 - 警告: X_conc_train['pred_head'] 包含 479478 个 NaN 值，填充为均值
# 第 1 折 - 训练浓度随机森林模型...
# 第 1 折 - 警告: X_conc_test['pred_head'] 包含 479492 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 2/10 折...
# 第 2 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 2 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 2 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 2 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 2 折 - 准备浓度训练数据...
# 第 2 折 - pred_head_train 中的 NaN: 0
# 第 2 折 - 警告: X_conc_train['pred_head'] 包含 479117 个 NaN 值，填充为均值
# 第 2 折 - 训练浓度随机森林模型...
# 第 2 折 - 警告: X_conc_test['pred_head'] 包含 479433 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 3/10 折...
# 第 3 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 3 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 3 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 3 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 3 折 - 准备浓度训练数据...
# 第 3 折 - pred_head_train 中的 NaN: 0
# 第 3 折 - 警告: X_conc_train['pred_head'] 包含 479599 个 NaN 值，填充为均值
# 第 3 折 - 训练浓度随机森林模型...
# 第 3 折 - 警告: X_conc_test['pred_head'] 包含 479179 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 4/10 折...
# 第 4 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 4 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 4 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 4 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 4 折 - 准备浓度训练数据...
# 第 4 折 - pred_head_train 中的 NaN: 0
# 第 4 折 - 警告: X_conc_train['pred_head'] 包含 479661 个 NaN 值，填充为均值
# 第 4 折 - 训练浓度随机森林模型...
# 第 4 折 - 警告: X_conc_test['pred_head'] 包含 479651 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 5/10 折...
# 第 5 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 5 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 5 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 5 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 5 折 - 准备浓度训练数据...
# 第 5 折 - pred_head_train 中的 NaN: 0
# 第 5 折 - 警告: X_conc_train['pred_head'] 包含 479987 个 NaN 值，填充为均值
# 第 5 折 - 训练浓度随机森林模型...
# 第 5 折 - 警告: X_conc_test['pred_head'] 包含 479357 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 6/10 折...
# 第 6 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 6 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 6 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 6 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 6 折 - 准备浓度训练数据...
# 第 6 折 - pred_head_train 中的 NaN: 0
# 第 6 折 - 警告: X_conc_train['pred_head'] 包含 479391 个 NaN 值，填充为均值
# 第 6 折 - 训练浓度随机森林模型...
# 第 6 折 - 警告: X_conc_test['pred_head'] 包含 480012 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 7/10 折...
# 第 7 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 7 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 7 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 7 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 7 折 - 准备浓度训练数据...
# 第 7 折 - pred_head_train 中的 NaN: 0
# 第 7 折 - 警告: X_conc_train['pred_head'] 包含 479556 个 NaN 值，填充为均值
# 第 7 折 - 训练浓度随机森林模型...
# 第 7 折 - 警告: X_conc_test['pred_head'] 包含 479392 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 8/10 折...
# 第 8 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 8 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 8 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 8 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 8 折 - 准备浓度训练数据...
# 第 8 折 - pred_head_train 中的 NaN: 0
# 第 8 折 - 警告: X_conc_train['pred_head'] 包含 479518 个 NaN 值，填充为均值
# 第 8 折 - 训练浓度随机森林模型...
# 第 8 折 - 警告: X_conc_test['pred_head'] 包含 479489 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 9/10 折...
# 第 9 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 9 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 9 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 9 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 9 折 - 准备浓度训练数据...
# 第 9 折 - pred_head_train 中的 NaN: 0
# 第 9 折 - 警告: X_conc_train['pred_head'] 包含 479531 个 NaN 值，填充为均值
# 第 9 折 - 训练浓度随机森林模型...
# 第 9 折 - 警告: X_conc_test['pred_head'] 包含 479377 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
#
# 处理第 10/10 折...
# 第 10 折 - 训练集形状: X_head_train=(4795200, 16), y_head_train=4795200
# 第 10 折 - 测试集形状: X_head_test=(532800, 16), y_head_test=532800
# 第 10 折 - 检查 X_head_train 中的 NaN 或无穷值:
# NaN: 0
# 无穷值: 0
# 第 10 折 - 训练水头随机森林模型...
# 无法获取水头模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 第 10 折 - 准备浓度训练数据...
# 第 10 折 - pred_head_train 中的 NaN: 0
# 第 10 折 - 警告: X_conc_train['pred_head'] 包含 479362 个 NaN 值，填充为均值
# 第 10 折 - 训练浓度随机森林模型...
# 第 10 折 - 警告: X_conc_test['pred_head'] 包含 479818 个 NaN 值，填充为均值
# 无法获取浓度模型的特征重要性: get_feature_importances
# 跳过特征重要性分析，继续训练...
# 无法使用 cuML 原生方法保存模型: save
# 尝试使用 pickle 保存...
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 22836 (\N{CJK UNIFIED IDEOGRAPH-5934}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 27169 (\N{CJK UNIFIED IDEOGRAPH-6A21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 22411 (\N{CJK UNIFIED IDEOGRAPH-578B}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 27987 (\N{CJK UNIFIED IDEOGRAPH-6D53}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:455: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 22836 (\N{CJK UNIFIED IDEOGRAPH-5934}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 27169 (\N{CJK UNIFIED IDEOGRAPH-6A21}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 22411 (\N{CJK UNIFIED IDEOGRAPH-578B}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 27987 (\N{CJK UNIFIED IDEOGRAPH-6D53}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:456: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'feature_importance.png'), dpi=300)
# 📊 平均训练集结果 (10折交叉验证):
#
# 🔹 水头指标:
# MSE  : 14.2669
# RMSE : 3.7771
# MAE  : 2.8529
# R2   : 0.5921
#
# 🔹 浓度指标:
# MSE  : 2.1772
# RMSE : 1.4755
# MAE  : 0.1758
# R2   : 0.7772
#
# 📊 平均测试集结果 (10折交叉验证):
#
# 🔹 水头指标:
# MSE  : 14.2708
# RMSE : 3.7777
# MAE  : 2.8532
# R2   : 0.5920
#
# 🔹 浓度指标:
# MSE  : 2.2931
# RMSE : 1.5132
# MAE  : 0.1775
# R2   : 0.7656
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 22836 (\N{CJK UNIFIED IDEOGRAPH-5934}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 27987 (\N{CJK UNIFIED IDEOGRAPH-6D53}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:518: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 22836 (\N{CJK UNIFIED IDEOGRAPH-5934}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 27987 (\N{CJK UNIFIED IDEOGRAPH-6D53}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /tmp/ipykernel_2396/1458317985.py:519: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   plt.savefig(os.path.join(config['save_path'], 'predictions_vs_truth.png'), dpi=300)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22836 (\N{CJK UNIFIED IDEOGRAPH-5934}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27169 (\N{CJK UNIFIED IDEOGRAPH-6A21}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22411 (\N{CJK UNIFIED IDEOGRAPH-578B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27987 (\N{CJK UNIFIED IDEOGRAPH-6D53}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import os

# 配置保存路径
save_path = './saved_models/dual_guass_rf'
os.makedirs(save_path, exist_ok=True)

# 整理平均指标为 DataFrame
metrics_data = {
    'Metric': ['mse', 'rmse', 'mae', 'r2'],
    'Head_Train': [avg_head_train_metrics[k] for k in ['mse', 'rmse', 'mae', 'r2']],
    'Conc_Train': [avg_conc_train_metrics[k] for k in ['mse', 'rmse', 'mae',  'r2']],
    'Head_Test': [avg_head_test_metrics[k] for k in ['mse', 'rmse', 'mae',  'r2']],
    'Conc_Test': [avg_conc_test_metrics[k] for k in ['mse', 'rmse', 'mae',  'r2']]
}

# 创建 DataFrame 并保存为 CSV
metrics_df = pd.DataFrame(metrics_data)
metrics_df.to_csv(os.path.join(save_path, 'average_metrics_kfold.csv'), index=False)

print(f"平均指标已保存至: {os.path.join(save_path, 'average_metrics_kfold.csv')}")
# Out:
# 平均指标已保存至: ./saved_models/dual_guass_rf/average_metrics_kfold.csv
